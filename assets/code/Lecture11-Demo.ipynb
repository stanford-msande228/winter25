# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.pipeline import Pipeline, make_pipeline
from sklearn.preprocessing import PolynomialFeatures, StandardScaler
from sklearn.linear_model import LinearRegression, LassoCV, ElasticNetCV, RidgeCV, Ridge, Lasso
from sklearn.ensemble import RandomForestRegressor, GradientBoostingRegressor
from sklearn.tree import DecisionTreeRegressor
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.model_selection import cross_val_score, KFold, GridSearchCV
from sklearn.metrics import mean_squared_error, r2_score
import patsy
import warnings
from sklearn.base import BaseEstimator, clone
import statsmodels.api as sm
warnings.simplefilter('ignore')
np.random.seed(1234)

# %%
# simple scalar regression "population" dgp
n = 10000
W = np.random.uniform(0, 1, size=(n, 1))
y = np.exp(2 * W[:, 0])
grid = np.linspace(0, 1, 1000).reshape(-1, 1)

# %%
# Let's fit BLPs with polynomial features
dtr = lambda d: DecisionTreeRegressor(max_depth=d)
pred1 = dtr(5).fit(W, y).predict(grid)

# %%
# even 3rd degree polynomial is good enough
plt.plot(grid, pred1)
plt.plot(grid, np.exp(2 * grid))
plt.show()

# %%
# Now let's go to finite sample and noisy data
n = 5000
W = np.random.uniform(0, 1, size=(n, 1))
y = np.exp(2 * W[:, 0]) + np.random.normal(0, 5, size=n)
grid = np.linspace(0, 1, 1000).reshape(-1, 1)

# %%
# Let's fit BLPs with polynomial features
dtr = lambda d: DecisionTreeRegressor(max_depth=d)
pred1 = dtr(5).fit(W, y).predict(grid)

# %%
# It is very noisy!
plt.plot(grid, pred1)
plt.plot(grid, np.exp(2 * grid))
plt.show()

# %%
# Let's fit BLPs with polynomial features
dtr = lambda d: RandomForestRegressor(n_estimators=1000, max_depth=d)
pred1 = dtr(10).fit(W, y).predict(grid)

# %%
# It is very noisy!
plt.plot(grid, pred1)
plt.plot(grid, np.exp(2 * grid))
plt.show()

# %%
# !pip install econml
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting econml
#   Using cached econml-0.15.1-cp312-cp312-win_amd64.whl.metadata (39 kB)
# Requirement already satisfied: numpy<2 in c:\programdata\anaconda3\lib\site-packages (from econml) (1.26.4)
# Requirement already satisfied: scipy>1.4.0 in c:\programdata\anaconda3\lib\site-packages (from econml) (1.13.1)
# Requirement already satisfied: scikit-learn<1.6,>=1.0 in c:\programdata\anaconda3\lib\site-packages (from econml) (1.4.2)
# Collecting sparse (from econml)
#   Downloading sparse-0.15.5-py2.py3-none-any.whl.metadata (4.4 kB)
# Requirement already satisfied: joblib>=0.13.0 in c:\programdata\anaconda3\lib\site-packages (from econml) (1.4.2)
# Requirement already satisfied: statsmodels>=0.10 in c:\programdata\anaconda3\lib\site-packages (from econml) (0.14.2)
# Requirement already satisfied: pandas>1.0 in c:\programdata\anaconda3\lib\site-packages (from econml) (2.2.2)
# Collecting shap<0.44.0,>=0.38.1 (from econml)
#   Using cached shap-0.43.0.tar.gz (389 kB)
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# Requirement already satisfied: lightgbm in c:\programdata\anaconda3\lib\site-packages (from econml) (4.5.0)
# Requirement already satisfied: packaging in c:\programdata\anaconda3\lib\site-packages (from econml) (23.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\programdata\anaconda3\lib\site-packages (from pandas>1.0->econml) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\programdata\anaconda3\lib\site-packages (from pandas>1.0->econml) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\programdata\anaconda3\lib\site-packages (from pandas>1.0->econml) (2023.3)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\programdata\anaconda3\lib\site-packages (from scikit-learn<1.6,>=1.0->econml) (2.2.0)
# Requirement already satisfied: tqdm>=4.27.0 in c:\programdata\anaconda3\lib\site-packages (from shap<0.44.0,>=0.38.1->econml) (4.66.4)
# Collecting slicer==0.0.7 (from shap<0.44.0,>=0.38.1->econml)
#   Using cached slicer-0.0.7-py3-none-any.whl.metadata (3.7 kB)
# Requirement already satisfied: numba in c:\programdata\anaconda3\lib\site-packages (from shap<0.44.0,>=0.38.1->econml) (0.59.1)
# Requirement already satisfied: cloudpickle in c:\programdata\anaconda3\lib\site-packages (from shap<0.44.0,>=0.38.1->econml) (2.2.1)
# Requirement already satisfied: patsy>=0.5.6 in c:\programdata\anaconda3\lib\site-packages (from statsmodels>=0.10->econml) (0.5.6)
# Requirement already satisfied: llvmlite<0.43,>=0.42.0dev0 in c:\programdata\anaconda3\lib\site-packages (from numba->shap<0.44.0,>=0.38.1->econml) (0.42.0)
# Requirement already satisfied: six in c:\programdata\anaconda3\lib\site-packages (from patsy>=0.5.6->statsmodels>=0.10->econml) (1.16.0)
# Requirement already satisfied: colorama in c:\programdata\anaconda3\lib\site-packages (from tqdm>=4.27.0->shap<0.44.0,>=0.38.1->econml) (0.4.6)
# Using cached econml-0.15.1-cp312-cp312-win_amd64.whl (2.0 MB)
# Using cached slicer-0.0.7-py3-none-any.whl (14 kB)
# Downloading sparse-0.15.5-py2.py3-none-any.whl (117 kB)
#    ---------------------------------------- 0.0/117.4 kB ? eta -:--:--
#    ---------- ---------------------------- 30.7/117.4 kB 660.6 kB/s eta 0:00:01
#    -------------------------------------- - 112.6/117.4 kB 2.2 MB/s eta 0:00:01
#    ---------------------------------------- 117.4/117.4 kB 1.4 MB/s eta 0:00:00
# Building wheels for collected packages: shap
#   Building wheel for shap (pyproject.toml): started
#   Building wheel for shap (pyproject.toml): finished with status 'done'
#   Created wheel for shap: filename=shap-0.43.0-cp312-cp312-win_amd64.whl size=445904 sha256=16c615d2b0dbc1cfa49056957eebbcd0c70dbf0e92a3ba01e4dfde86b2ab0244
#   Stored in directory: c:\users\vasilis\appdata\local\pip\cache\wheels\e0\cb\3e\46cb0f77e2e4f5aa9fd5d399dedb3ba84f91f0c49e3db7d0e1
# Successfully built shap
# Installing collected packages: slicer, sparse, shap, econml
# Successfully installed econml-0.15.1 shap-0.43.0 slicer-0.0.7 sparse-0.15.5
# DEPRECATION: Loading egg at c:\programdata\anaconda3\lib\site-packages\cvxopt-1.3.2-py3.12-win-amd64.egg is deprecated. pip 24.3 will enforce this behaviour change. A possible replacement is to use pip for package installation.. Discussion can be found at https://github.com/pypa/pip/issues/12330

# %%
from econml.grf import RegressionForest

# Let's fit BLPs with polynomial features
dtr = lambda d: RegressionForest(n_estimators=1000, 
                                 honest=True,
                                 max_samples=.1,
                                 inference=False,
                                 max_depth=d, min_samples_split=2, min_samples_leaf=1)
pred1 = dtr(10).fit(W, y).predict(grid)

# %%
# It is very noisy!
plt.plot(grid, pred1)
plt.plot(grid, np.exp(2 * grid))
plt.show()

# %%
# Let's fit BLPs with polynomial features
dtr = lambda d: GradientBoostingRegressor(n_estimators=1000, max_depth=d, n_iter_no_change=5)
pred1 = dtr(2).fit(W, y).predict(grid)

# %%
# It is very noisy!
plt.plot(grid, pred1)
plt.plot(grid, np.exp(2 * grid))
plt.show()

# %%
from sklearn.neural_network import MLPRegressor
# Let's fit BLPs with polynomial features
dtr = lambda d: MLPRegressor()
pred1 = dtr(2).fit(W, y).predict(grid)

# %%
# It is very noisy!
plt.plot(grid, pred1)
plt.plot(grid, np.exp(2 * grid))
plt.show()

# %%
from sklearn.ensemble import StackingRegressor
# Let's fit BLPs with polynomial features
est1 = ('nnet', MLPRegressor())
est2 = ('ols', LinearRegression())
est3 = ('polylasso', make_pipeline(PolynomialFeatures(degree=3, include_bias=False), LassoCV()))
est4 = ('rf', RandomForestRegressor(min_samples_leaf=20))
est5 = ('gbf', GradientBoostingRegressor(n_estimators=50, max_depth=2, n_iter_no_change=5))
stack = StackingRegressor([est1, est2, est3, est4, est5], final_estimator=LinearRegression(), n_jobs=-1,)
pred1 = stack.fit(W, y).predict(grid)

# %%
# It is very noisy!
plt.plot(grid, pred1)
plt.plot(grid, np.exp(2 * grid))
plt.show()

# %%
# !pip install flaml
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting flaml
#   Downloading FLAML-2.3.3-py3-none-any.whl.metadata (16 kB)
# Requirement already satisfied: NumPy>=1.17 in c:\programdata\anaconda3\lib\site-packages (from flaml) (1.26.4)
# Downloading FLAML-2.3.3-py3-none-any.whl (314 kB)
#    ---------------------------------------- 0.0/314.2 kB ? eta -:--:--
#    ------------------------ --------------- 194.6/314.2 kB 5.8 MB/s eta 0:00:01
#    ---------------------------------------- 314.2/314.2 kB 4.8 MB/s eta 0:00:00
# Installing collected packages: flaml
# Successfully installed flaml-2.3.3
# DEPRECATION: Loading egg at c:\programdata\anaconda3\lib\site-packages\cvxopt-1.3.2-py3.12-win-amd64.egg is deprecated. pip 24.3 will enforce this behaviour change. A possible replacement is to use pip for package installation.. Discussion can be found at https://github.com/pypa/pip/issues/12330

# %%
from flaml import AutoML

automl = AutoML(task='regression', time_budget=10, early_stop=True,
                eval_method='cv', n_splits=3, metric='r2',
                verbose=3)
automl.fit(W, y)
pred1 = automl.predict(grid)
# Out:
# [flaml.automl.logger: 02-11 14:20:13] {1728} INFO - task = regression
# [flaml.automl.logger: 02-11 14:20:13] {1739} INFO - Evaluation method: cv
# [flaml.automl.logger: 02-11 14:20:13] {1838} INFO - Minimizing error metric: 1-r2
# [flaml.automl.logger: 02-11 14:20:13] {1955} INFO - List of ML learners in AutoML Run: ['lgbm', 'rf', 'xgboost', 'extra_tree', 'xgb_limitdepth', 'sgd']
# [flaml.automl.logger: 02-11 14:20:13] {2258} INFO - iteration 0, current learner lgbm
# [flaml.automl.logger: 02-11 14:20:14] {2393} INFO - Estimated sufficient time budget=862s. Estimated necessary time budget=6s.
# [flaml.automl.logger: 02-11 14:20:14] {2442} INFO -  at 0.1s,	estimator lgbm's best error=0.9453,	best estimator lgbm's best error=0.9453
# [flaml.automl.logger: 02-11 14:20:14] {2258} INFO - iteration 1, current learner lgbm
# [flaml.automl.logger: 02-11 14:20:14] {2442} INFO -  at 0.2s,	estimator lgbm's best error=0.9453,	best estimator lgbm's best error=0.9453
# [flaml.automl.logger: 02-11 14:20:14] {2258} INFO - iteration 2, current learner lgbm
# [flaml.automl.logger: 02-11 14:20:14] {2442} INFO -  at 0.2s,	estimator lgbm's best error=0.9103,	best estimator lgbm's best error=0.9103
# [flaml.automl.logger: 02-11 14:20:14] {2258} INFO - iteration 3, current learner lgbm
# [flaml.automl.logger: 02-11 14:20:14] {2442} INFO -  at 0.3s,	estimator lgbm's best error=0.9103,	best estimator lgbm's best error=0.9103
# [flaml.automl.logger: 02-11 14:20:14] {2258} INFO - iteration 4, current learner lgbm
# [flaml.automl.logger: 02-11 14:20:14] {2442} INFO -  at 0.3s,	estimator lgbm's best error=0.9103,	best estimator lgbm's best error=0.9103
# [flaml.automl.logger: 02-11 14:20:14] {2258} INFO - iteration 5, current learner sgd
# [flaml.automl.logger: 02-11 14:20:14] {2442} INFO -  at 0.3s,	estimator sgd's best error=1.0015,	best estimator lgbm's best error=0.9103
# [flaml.automl.logger: 02-11 14:20:14] {2258} INFO - iteration 6, current learner lgbm
# [flaml.automl.logger: 02-11 14:20:14] {2442} INFO -  at 0.4s,	estimator lgbm's best error=0.9080,	best estimator lgbm's best error=0.9080
# [flaml.automl.logger: 02-11 14:20:14] {2258} INFO - iteration 7, current learner lgbm
# [flaml.automl.logger: 02-11 14:20:14] {2442} INFO -  at 0.4s,	estimator lgbm's best error=0.9080,	best estimator lgbm's best error=0.9080
# [flaml.automl.logger: 02-11 14:20:14] {2258} INFO - iteration 8, current learner lgbm
# [flaml.automl.logger: 02-11 14:20:14] {2442} INFO -  at 0.5s,	estimator lgbm's best error=0.9036,	best estimator lgbm's best error=0.9036
# [flaml.automl.logger: 02-11 14:20:14] {2258} INFO - iteration 9, current learner sgd
# [flaml.automl.logger: 02-11 14:20:14] {2442} INFO -  at 0.5s,	estimator sgd's best error=1.0015,	best estimator lgbm's best error=0.9036
# [flaml.automl.logger: 02-11 14:20:14] {2258} INFO - iteration 10, current learner lgbm
# [flaml.automl.logger: 02-11 14:20:14] {2442} INFO -  at 0.6s,	estimator lgbm's best error=0.9033,	best estimator lgbm's best error=0.9033
# [flaml.automl.logger: 02-11 14:20:14] {2258} INFO - iteration 11, current learner lgbm
# [flaml.automl.logger: 02-11 14:20:14] {2442} INFO -  at 0.6s,	estimator lgbm's best error=0.9033,	best estimator lgbm's best error=0.9033
# [flaml.automl.logger: 02-11 14:20:14] {2258} INFO - iteration 12, current learner lgbm
# [flaml.automl.logger: 02-11 14:20:14] {2442} INFO -  at 1.1s,	estimator lgbm's best error=0.9033,	best estimator lgbm's best error=0.9033
# [flaml.automl.logger: 02-11 14:20:14] {2258} INFO - iteration 13, current learner xgboost
# [flaml.automl.logger: 02-11 14:20:15] {2442} INFO -  at 1.1s,	estimator xgboost's best error=0.9453,	best estimator lgbm's best error=0.9033
# [flaml.automl.logger: 02-11 14:20:15] {2258} INFO - iteration 14, current learner xgboost
# [flaml.automl.logger: 02-11 14:20:15] {2442} INFO -  at 1.2s,	estimator xgboost's best error=0.9453,	best estimator lgbm's best error=0.9033
# [flaml.automl.logger: 02-11 14:20:15] {2258} INFO - iteration 15, current learner xgboost
# [flaml.automl.logger: 02-11 14:20:15] {2442} INFO -  at 1.2s,	estimator xgboost's best error=0.9111,	best estimator lgbm's best error=0.9033
# [flaml.automl.logger: 02-11 14:20:15] {2258} INFO - iteration 16, current learner xgboost
# [flaml.automl.logger: 02-11 14:20:15] {2442} INFO -  at 1.3s,	estimator xgboost's best error=0.9111,	best estimator lgbm's best error=0.9033
# [flaml.automl.logger: 02-11 14:20:15] {2258} INFO - iteration 17, current learner lgbm
# [flaml.automl.logger: 02-11 14:20:15] {2442} INFO -  at 1.4s,	estimator lgbm's best error=0.9033,	best estimator lgbm's best error=0.9033
# [flaml.automl.logger: 02-11 14:20:15] {2258} INFO - iteration 18, current learner xgboost
# [flaml.automl.logger: 02-11 14:20:15] {2442} INFO -  at 1.4s,	estimator xgboost's best error=0.9111,	best estimator lgbm's best error=0.9033
# [flaml.automl.logger: 02-11 14:20:15] {2258} INFO - iteration 19, current learner xgboost
# [flaml.automl.logger: 02-11 14:20:15] {2442} INFO -  at 1.5s,	estimator xgboost's best error=0.9111,	best estimator lgbm's best error=0.9033
# [flaml.automl.logger: 02-11 14:20:15] {2258} INFO - iteration 20, current learner xgboost
# [flaml.automl.logger: 02-11 14:20:15] {2442} INFO -  at 1.5s,	estimator xgboost's best error=0.9076,	best estimator lgbm's best error=0.9033
# [flaml.automl.logger: 02-11 14:20:15] {2258} INFO - iteration 21, current learner extra_tree
# [flaml.automl.logger: 02-11 14:20:15] {2442} INFO -  at 1.8s,	estimator extra_tree's best error=0.9024,	best estimator extra_tree's best error=0.9024
# [flaml.automl.logger: 02-11 14:20:15] {2258} INFO - iteration 22, current learner rf
# [flaml.automl.logger: 02-11 14:20:16] {2442} INFO -  at 2.2s,	estimator rf's best error=0.9042,	best estimator extra_tree's best error=0.9024
# [flaml.automl.logger: 02-11 14:20:16] {2258} INFO - iteration 23, current learner rf
# [flaml.automl.logger: 02-11 14:20:16] {2442} INFO -  at 2.6s,	estimator rf's best error=0.9042,	best estimator extra_tree's best error=0.9024
# [flaml.automl.logger: 02-11 14:20:16] {2258} INFO - iteration 24, current learner rf
# [flaml.automl.logger: 02-11 14:20:16] {2442} INFO -  at 2.9s,	estimator rf's best error=0.9042,	best estimator extra_tree's best error=0.9024
# [flaml.automl.logger: 02-11 14:20:16] {2258} INFO - iteration 25, current learner extra_tree
# [flaml.automl.logger: 02-11 14:20:17] {2442} INFO -  at 3.2s,	estimator extra_tree's best error=0.9024,	best estimator extra_tree's best error=0.9024
# [flaml.automl.logger: 02-11 14:20:17] {2258} INFO - iteration 26, current learner extra_tree
# [flaml.automl.logger: 02-11 14:20:17] {2442} INFO -  at 3.7s,	estimator extra_tree's best error=0.9008,	best estimator extra_tree's best error=0.9008
# [flaml.automl.logger: 02-11 14:20:17] {2258} INFO - iteration 27, current learner rf
# [flaml.automl.logger: 02-11 14:20:18] {2442} INFO -  at 4.1s,	estimator rf's best error=0.9042,	best estimator extra_tree's best error=0.9008
# [flaml.automl.logger: 02-11 14:20:18] {2258} INFO - iteration 28, current learner extra_tree
# [flaml.automl.logger: 02-11 14:20:18] {2442} INFO -  at 4.6s,	estimator extra_tree's best error=0.9008,	best estimator extra_tree's best error=0.9008
# [flaml.automl.logger: 02-11 14:20:18] {2258} INFO - iteration 29, current learner extra_tree
# [flaml.automl.logger: 02-11 14:20:18] {2442} INFO -  at 4.9s,	estimator extra_tree's best error=0.9008,	best estimator extra_tree's best error=0.9008
# [flaml.automl.logger: 02-11 14:20:18] {2258} INFO - iteration 30, current learner extra_tree
# [flaml.automl.logger: 02-11 14:20:19] {2442} INFO -  at 5.5s,	estimator extra_tree's best error=0.9008,	best estimator extra_tree's best error=0.9008
# [flaml.automl.logger: 02-11 14:20:19] {2258} INFO - iteration 31, current learner rf
# [flaml.automl.logger: 02-11 14:20:19] {2442} INFO -  at 6.0s,	estimator rf's best error=0.9039,	best estimator extra_tree's best error=0.9008
# [flaml.automl.logger: 02-11 14:20:19] {2258} INFO - iteration 32, current learner lgbm
# [flaml.automl.logger: 02-11 14:20:20] {2442} INFO -  at 6.1s,	estimator lgbm's best error=0.9033,	best estimator extra_tree's best error=0.9008
# [flaml.automl.logger: 02-11 14:20:20] {2258} INFO - iteration 33, current learner xgboost
# [flaml.automl.logger: 02-11 14:20:20] {2442} INFO -  at 6.2s,	estimator xgboost's best error=0.9076,	best estimator extra_tree's best error=0.9008
# [flaml.automl.logger: 02-11 14:20:20] {2258} INFO - iteration 34, current learner extra_tree
# [flaml.automl.logger: 02-11 14:20:20] {2442} INFO -  at 6.7s,	estimator extra_tree's best error=0.8999,	best estimator extra_tree's best error=0.8999
# [flaml.automl.logger: 02-11 14:20:20] {2258} INFO - iteration 35, current learner xgboost
# [flaml.automl.logger: 02-11 14:20:20] {2442} INFO -  at 6.8s,	estimator xgboost's best error=0.9076,	best estimator extra_tree's best error=0.8999
# [flaml.automl.logger: 02-11 14:20:20] {2258} INFO - iteration 36, current learner xgboost
# [flaml.automl.logger: 02-11 14:20:20] {2442} INFO -  at 6.9s,	estimator xgboost's best error=0.9076,	best estimator extra_tree's best error=0.8999
# [flaml.automl.logger: 02-11 14:20:20] {2258} INFO - iteration 37, current learner extra_tree
# [flaml.automl.logger: 02-11 14:20:21] {2442} INFO -  at 7.5s,	estimator extra_tree's best error=0.8992,	best estimator extra_tree's best error=0.8992
# [flaml.automl.logger: 02-11 14:20:21] {2258} INFO - iteration 38, current learner extra_tree
# [flaml.automl.logger: 02-11 14:20:21] {2442} INFO -  at 8.1s,	estimator extra_tree's best error=0.8992,	best estimator extra_tree's best error=0.8992
# [flaml.automl.logger: 02-11 14:20:21] {2258} INFO - iteration 39, current learner extra_tree
# [flaml.automl.logger: 02-11 14:20:22] {2442} INFO -  at 8.6s,	estimator extra_tree's best error=0.8992,	best estimator extra_tree's best error=0.8992
# [flaml.automl.logger: 02-11 14:20:22] {2258} INFO - iteration 40, current learner xgboost
# [flaml.automl.logger: 02-11 14:20:22] {2442} INFO -  at 8.7s,	estimator xgboost's best error=0.9068,	best estimator extra_tree's best error=0.8992
# [flaml.automl.logger: 02-11 14:20:22] {2258} INFO - iteration 41, current learner extra_tree
# [flaml.automl.logger: 02-11 14:20:23] {2442} INFO -  at 9.3s,	estimator extra_tree's best error=0.8992,	best estimator extra_tree's best error=0.8992
# [flaml.automl.logger: 02-11 14:20:23] {2258} INFO - iteration 42, current learner extra_tree
# [flaml.automl.logger: 02-11 14:20:23] {2442} INFO -  at 9.7s,	estimator extra_tree's best error=0.8992,	best estimator extra_tree's best error=0.8992
# [flaml.automl.logger: 02-11 14:20:23] {2258} INFO - iteration 43, current learner xgb_limitdepth
# [flaml.automl.logger: 02-11 14:20:23] {2442} INFO -  at 9.8s,	estimator xgb_limitdepth's best error=0.9262,	best estimator extra_tree's best error=0.8992
# [flaml.automl.logger: 02-11 14:20:23] {2258} INFO - iteration 44, current learner lgbm
# [flaml.automl.logger: 02-11 14:20:23] {2442} INFO -  at 9.9s,	estimator lgbm's best error=0.9033,	best estimator extra_tree's best error=0.8992
# [flaml.automl.logger: 02-11 14:20:23] {2258} INFO - iteration 45, current learner sgd
# [flaml.automl.logger: 02-11 14:20:23] {2442} INFO -  at 10.0s,	estimator sgd's best error=1.0015,	best estimator extra_tree's best error=0.8992
# [flaml.automl.logger: 02-11 14:20:23] {2258} INFO - iteration 46, current learner sgd
# [flaml.automl.logger: 02-11 14:20:23] {2442} INFO -  at 10.0s,	estimator sgd's best error=1.0015,	best estimator extra_tree's best error=0.8992
# [flaml.automl.logger: 02-11 14:20:23] {2685} INFO - retrain extra_tree for 0.1s
# [flaml.automl.logger: 02-11 14:20:23] {2688} INFO - retrained model: ExtraTreesRegressor(max_features=0.8642366754483964, max_leaf_nodes=6,
#                     n_estimators=15, n_jobs=-1, random_state=12032022)
# [flaml.automl.logger: 02-11 14:20:23] {1985} INFO - fit succeeded
# [flaml.automl.logger: 02-11 14:20:23] {1986} INFO - Time taken to find the best model: 7.540608167648315

# %%
# It is very noisy!
plt.plot(grid, pred1)
plt.plot(grid, np.exp(2 * grid))
plt.show()
